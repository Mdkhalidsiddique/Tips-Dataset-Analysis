# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tips.csv")

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'pct_bill'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
# 5      4.71
# 6      2.00
# 7      3.12
# 8      1.96
# 9      3.23
# 10     1.71
# 11     5.00
# 12     1.57
# 13     3.00
# 14     3.02
# 15     3.92
# 16     1.67
# 17     3.71
# 18     3.50
# 19     3.35
# 20     4.08
# 21     2.75
# 22     2.23
# 23     7.58
# 24     3.18
# 25     2.34
# 26     2.00
# 27     2.00
# 28     4.30
# 29     3.00
#        ...
# 214    6.50
# 215    1.10
# 216    3.00
# 217    1.50
# 218    1.44
# 219    3.09
# 220    2.20
# 221    3.48
# 222    1.92
# 223    3.00
# 224    1.58
# 225    2.50
# 226    2.00
# 227    3.00
# 228    2.72
# 229    2.88
# 230    2.00
# 231    3.00
# 232    3.39
# 233    1.47
# 234    3.00
# 235    1.25
# 236    1.00
# 237    1.17
# 238    4.67
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['tip'].mean()
# Out:
# 2.9982786885245902

# %%
average_tip = df['tip'].median()
average_tip
# Out:
# 2.9

# %%
df.boxplot(column=['tip'])

# %%
df.boxplot(column=['total_bill'])

# %%
print(df.sex.value_counts())
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
print(df.sex.value_counts(normalize = True)*100)
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000262F0F08C50>,
# ...
#       dtype=object)

# %%
df.sex.value_counts( ).plot(kind = 'bar')

# %%
df.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.catplot(x="day", y="total_bill", data=df);

# %%
sns.catplot(x="tip", y="sex", data=df);

# %%
sns.lineplot(x="size", y="tip", data=df);

# %%
sns.catplot(x="smoker", y="tip", kind = 'swarm',  data=df);

# %%
sns.catplot(x="time", y="tip", data=df);

# %%
df.shape[0]
# Out:
# 244

# %%
sns.catplot(x="size", y="pct_bill", data=df);

# %%
sns.barplot(x="sex", y="pct_bill", data=df);

# %%
plt.scatter(x = "total_bill", y = "tip")

# %%
plt.scatter(x = "total_bill", y = "pct_tip")
